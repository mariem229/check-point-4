# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        0.75  1.2500      0.12         1.6
# 3        1.00  1.2500      0.12         inf

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %%
data_frame= pd.read_csv('C:\\Users\\Mkarry\\Market_Basket_Optimisation.csv', sep= ',')

# %%
#preprocessing 
import numpy as np 
purchaser = []
for i in range(0, 7500):
    purchaser.append([str(data_frame.values[i,j]) for j in range(0, 20)])

purchaser = np.array(purchaser) # create numpy array
purchaser.shape # checking shape
# Out:
# (7500, 20)

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit( purchaser).transform( purchaser)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False    False              False      False    False        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False     True        False
# 3          False    False              False      False    False        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7495       False    False              False      False    False        False
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# 0     False           False      False        False  ...   False
# 1     False           False      False        False  ...   False
# 2     False           False      False        False  ...    True
# 3     False           False      False        False  ...   False
# 4     False           False      False        False  ...   False
# ...     ...             ...        ...          ...  ...     ...
# 7495  False           False      False        False  ...   False
# 7496  False           False      False        False  ...   False
# 7497  False           False      False        False  ...   False
# 7498  False           False      False        False  ...   False
# 7499  False           False      False        False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0              False        False       False             False
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 7495           False        False       False             False
# 7496           False        False       False             False
# 7497           False        False       False             False
# 7498           False        False       False             False
# 7499           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False  False        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False              True  False        False     False
# 4                 False             False  False        False     False
# ...                 ...               ...    ...          ...       ...
# 7495              False             False  False        False     False
# 7496              False             False  False        False     False
# 7497              False             False  False        False     False
# 7498              False             False  False        False     False
# 7499              False             False  False         True     False
#
# [7500 rows x 121 columns]

# %%
from mlxtend.frequent_patterns import apriori
apriori( df, min_support=0.01)
# Out:
#       support           itemsets
# 0    0.020267                (1)
# 1    0.033200                (4)
# 2    0.010800                (7)
# 3    0.014267                (8)
# 4    0.011467               (10)
# ..        ...                ...
# 514  0.011067   (72, 77, 71, 55)
# 515  0.017067  (72, 101, 77, 55)
# 516  0.015733  (72, 101, 77, 71)
# 517  0.010267  (72, 82, 101, 77)
# 518  0.011467  (72, 101, 83, 77)
#
# [519 rows x 2 columns]

# %%
frequent_itemsets=apriori(df, min_support=0.01, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#       support                                      itemsets
# 0    0.020267                                     (almonds)
# 1    0.033200                                     (avocado)
# 2    0.010800                              (barbecue sauce)
# 3    0.014267                                   (black tea)
# 4    0.011467                                  (body spray)
# ..        ...                                           ...
# 514  0.011067       (ground beef, mineral water, milk, nan)
# 515  0.017067  (ground beef, mineral water, spaghetti, nan)
# 516  0.015733         (mineral water, spaghetti, milk, nan)
# 517  0.010267    (mineral water, spaghetti, nan, olive oil)
# 518  0.011467     (pancakes, mineral water, spaghetti, nan)
#
# [519 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets, metric="confidence" , min_threshold=0.5) # associate itemsets with confidence over 50%
# Out:
#                                  antecedents           consequents  \
# 0                                  (almonds)                 (nan)
# 1                                  (avocado)                 (nan)
# 2                           (barbecue sauce)                 (nan)
# 3                                (black tea)                 (nan)
# 4                               (body spray)                 (nan)
# ..                                       ...                   ...
# 260                      (milk, ground beef)  (mineral water, nan)
# 261  (mineral water, spaghetti, ground beef)                 (nan)
# 262         (mineral water, spaghetti, milk)                 (nan)
# 263    (mineral water, spaghetti, olive oil)                 (nan)
# 264     (pancakes, mineral water, spaghetti)                 (nan)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.020267            1.000000  0.020267     1.00000  1.000000
# 1              0.033200            1.000000  0.033200     1.00000  1.000000
# 2              0.010800            1.000000  0.010800     1.00000  1.000000
# 3              0.014267            1.000000  0.014267     1.00000  1.000000
# 4              0.011467            1.000000  0.011467     1.00000  1.000000
# ..                  ...                 ...       ...         ...       ...
# 260            0.022000            0.238267  0.011067     0.50303  2.111207
# 261            0.017067            1.000000  0.017067     1.00000  1.000000
# 262            0.015733            1.000000  0.015733     1.00000  1.000000
# 263            0.010267            1.000000  0.010267     1.00000  1.000000
# 264            0.011467            1.000000  0.011467     1.00000  1.000000
#
#      leverage  conviction
# 0    0.000000         inf
# 1    0.000000         inf
# 2    0.000000         inf
# 3    0.000000         inf
# 4    0.000000         inf
# ..        ...         ...
# 260  0.005825    1.532756
# 261  0.000000         inf
# 262  0.000000         inf
# 263  0.000000         inf
# 264  0.000000         inf
#
# [265 rows x 9 columns]

# %%
association_rules(frequent_itemsets,metric="lift",min_threshold=1)
# Out:
#            antecedents                           consequents  \
# 0            (almonds)                                 (nan)
# 1                (nan)                             (almonds)
# 2      (mineral water)                             (avocado)
# 3            (avocado)                       (mineral water)
# 4            (avocado)                                 (nan)
# ...                ...                                   ...
# 1737  (spaghetti, nan)             (pancakes, mineral water)
# 1738        (pancakes)       (mineral water, spaghetti, nan)
# 1739   (mineral water)            (pancakes, spaghetti, nan)
# 1740       (spaghetti)        (pancakes, mineral water, nan)
# 1741             (nan)  (pancakes, mineral water, spaghetti)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               0.020267            1.000000  0.020267    1.000000  1.000000
# 1               1.000000            0.020267  0.020267    0.020267  1.000000
# 2               0.238267            0.033200  0.011467    0.048125  1.449559
# 3               0.033200            0.238267  0.011467    0.345382  1.449559
# 4               0.033200            1.000000  0.033200    1.000000  1.000000
# ...                  ...                 ...       ...         ...       ...
# 1737            0.174133            0.033733  0.011467    0.065850  1.952073
# 1738            0.095067            0.059733  0.011467    0.120617  2.019260
# 1739            0.238267            0.025200  0.011467    0.048125  1.909736
# 1740            0.174133            0.033733  0.011467    0.065850  1.952073
# 1741            1.000000            0.011467  0.011467    0.011467  1.000000
#
#       leverage  conviction
# 0     0.000000         inf
# 1     0.000000    1.000000
# 2     0.003556    1.015680
# 3     0.003556    1.163629
# 4     0.000000         inf
# ...        ...         ...
# 1737  0.005593    1.034381
# 1738  0.005788    1.069235
# 1739  0.005462    1.024084
# 1740  0.005593    1.034381
# 1741  0.000000    1.000000
#
# [1742 rows x 9 columns]
